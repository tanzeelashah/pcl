# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('student.csv')

# %%
df.head(2)
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
#
#    exam_score
# 0        30.2
# 1        25.0

# %%
import matplotlib .pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['sleep_hours'])
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8612\1145067361.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sleep_hours'])

# %%
df['sleep_hours'].skew()
# Out:
# -0.043222701395355605

# %%
sns.boxplot(df['sleep_hours'])
# Out:
# <Axes: ylabel='sleep_hours'>

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['previous_scores'])
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8612\3710180524.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['previous_scores'])

# %%
df['previous_scores'].skew()
# Out:
# 0.059656397269075255

# %%
sns.boxplot(df['previous_scores'])
# Out:
# <Axes: ylabel='previous_scores'>

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['hours_studied'])
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8612\144646230.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['hours_studied'])

# %%
df['hours_studied'].skew()
# Out:
# 0.1170569402464793

# %%
sns.boxplot(df['hours_studied'])
# Out:
# <Axes: ylabel='hours_studied'>

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['attendance_percent'])
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_12624\3914073659.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['attendance_percent'])

# %%
df['attendance_percent'].skew()
# Out:
# -0.07289045898328388

# %%
sns.boxplot(df['attendance_percent'])
# Out:
# <Axes: ylabel='attendance_percent'>

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['exam_score'])
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8612\2919122886.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['exam_score'])

# %%
df['exam_score'].skew()
# Out:
# 0.03257466628892812

# %%
sns.boxplot(df['exam_score'])
# Out:
# <Axes: ylabel='exam_score'>

# %%
print("mean value of exam_score",df['exam_score'].mean())
# Out:
# mean value of exam_score 33.955

# %%
print("mean value of exam_score",df['exam_score'].std())
# Out:
# mean value of exam_score 6.789548204712934

# %%
print("mean value of exam_score",df['exam_score'].min())
# Out:
# mean value of exam_score 17.1

# %%
print("mean value of exam_score",df['exam_score'].max())
# Out:
# mean value of exam_score 51.3

# %% [markdown]
# #finding the boundary values

# %%
print("highest allowed",df['exam_score'].mean()+3*df['exam_score'].std())
# Out:
# highest allowed 54.3236446141388

# %%
print("highest allowed",df['exam_score'].mean()- 3*df['exam_score'].std())
# Out:
# highest allowed 13.586355385861197

# %% [markdown]
# # finding outlier

# %%
df[(df['exam_score']>54.3)|(df['exam_score']<13.58)]
# Out:
# Empty DataFrame
# Columns: [student_id, hours_studied, sleep_hours, attendance_percent, previous_scores, exam_score]
# Index: []

# %%
df[(df['exam_score']<54.3)&(df['exam_score']>13.58)]
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %% [markdown]
# # all data is normal so apply z_score

# %% [markdown]
# # hour _studied

# %%
print("mean value of exam_score",df['hours_studied'].mean())
# Out:
# mean value of exam_score 6.3255

# %%
print("std value of exam_score",df['hours_studied'].std())
# Out:
# std value of exam_score 3.2273174058637246

# %%
print("min value of exam_score",df['hours_studied'].min())
# Out:
# min value of exam_score 1.0

# %%
print("max value of exam_score",df['hours_studied'].max())
# Out:
# max value of exam_score 12.0

# %% [markdown]
# # finding boundary

# %%
print("highest allowed",df['hours_studied'].mean()+3*df['exam_score'].std())
# Out:
# highest allowed 26.6941446141388

# %%
print("lowest allowed",df['hours_studied'].mean()-3*df['exam_score'].std())
# Out:
# lowest allowed -14.043144614138802

# %% [markdown]
# # find outlier

# %%
df[(df['hours_studied']>26.69)|(df['hours_studied']<-14.04)]
# Out:
# Empty DataFrame
# Columns: [student_id, hours_studied, sleep_hours, attendance_percent, previous_scores, exam_score]
# Index: []

# %% [markdown]
# # without outlier data

# %%
df[(df['hours_studied']<26.69)&(df['hours_studied']>-14.04)]
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %% [markdown]
# # sleep hour

# %%
print("mean value of exam_score",df['sleep_hours'].mean())
# Out:
# mean value of exam_score 6.621999999999999

# %%
print("std value of exam_score",df['sleep_hours'].std())
# Out:
# std value of exam_score 1.497138308767059

# %%
print("min value of exam_score",df['sleep_hours'].min())
# Out:
# min value of exam_score 4.0

# %%
print("max value of exam_score",df['sleep_hours'].max())
# Out:
# max value of exam_score 9.0

# %% [markdown]
# # finding boundary values  for  sleep

# %%
print("highest allowed",df['sleep_hours'].mean()+3*df['sleep_hours'].std())
# Out:
# highest allowed 11.113414926301175

# %%
print("lowest allowed",df['sleep_hours'].mean()-3*df['sleep_hours'].std())
# Out:
# lowest allowed 2.130585073698822

# %%
df[(df['sleep_hours']>11.11)|(df['sleep_hours']<2.13)]
# Out:
# Empty DataFrame
# Columns: [student_id, hours_studied, sleep_hours, attendance_percent, previous_scores, exam_score]
# Index: []

# %% [markdown]
# # finding outlier

# %%
df[(df['sleep_hours']<11.11)&(df['sleep_hours']>2.13)]
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %% [markdown]
# # attende

# %%
print("std value of exam_score",df['attendance_percent'].std())
# Out:
# std value of exam_score 14.249905227578703

# %%
print("mean is ",df['attendance_percent'].mean())
# Out:
# mean is  74.83

# %%
print("min is:",df['attendance_percent'].min())
# Out:
# min is: 50.3

# %%
print('max is:',df['attendance_percent'].max())
# Out:
# max is: 100.0

# %% [markdown]
# # finding boundary

# %%
print("highest allowed",df['attendance_percent'].mean()+3*df['attendance_percent'].std())
# Out:
# highest allowed 117.57971568273611

# %%
print("lowest allowed",df['attendance_percent'].mean()-3*df['attendance_percent'].std())
# Out:
# lowest allowed 32.08028431726389

# %% [markdown]
# # finding outlier

# %%
df[(df['attendance_percent']>117.57)|(df['attendance_percent']<32.08)]
# Out:
# Empty DataFrame
# Columns: [student_id, hours_studied, sleep_hours, attendance_percent, previous_scores, exam_score]
# Index: []

# %%
df[(df['attendance_percent']<117.57)&(df['attendance_percent']>32.08)]
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %% [markdown]
# # previous score

# %%
print("std value of exam_score",df['previous_scores'].std())
# Out:
# std value of exam_score 15.663868740499513

# %%
print("min value of exam_score",df['previous_scores'].min())
# Out:
# min value of exam_score 40

# %%
print("mx value of exam_score",df['previous_scores'].max())
# Out:
# mx value of exam_score 95

# %%
print("mean value of exam_score",df['previous_scores'].mean())
# Out:
# mean value of exam_score 66.8

# %% [markdown]
# # finding  boundry values

# %%
print("highest allowed",df['previous_scores'].mean()+3*df['previous_scores'].std())
# Out:
# highest allowed 113.79160622149854

# %%
print("lowest allowed",df['previous_scores'].mean()-3*df['previous_scores'].std())
# Out:
# lowest allowed 19.808393778501454

# %% [markdown]
# # trimming

# %%
df[(df['previous_scores']>113.79)|(df['previous_scores']<19.80)]
# Out:
# Empty DataFrame
# Columns: [student_id, hours_studied, sleep_hours, attendance_percent, previous_scores, exam_score]
# Index: []

# %%
df[(df['previous_scores']<113.79)|(df['previous_scores']>19.80)]
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...
